# %% [markdown]
# ## Compare performance, usability and accuracy of XGBoost and LGBM
#
# note XGBooting can not handle categorical features without converting the features to numeric values (one-hot encoding)
#
# Based on the sample data set, XGBoost provides more accurate predictions with higher variance than LGBM which has obviously faster performance

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### data set

# %%
boston = load_boston()
print (boston.keys())
print (boston.data.shape)
print (boston.feature_names)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])
# (506, 13)
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
df_data = pd.DataFrame(boston.data)
df_data.columns = boston.feature_names
df_data['PRICE'] = boston.target
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# prepare data
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
X, y = df_data.iloc[:,:-1],df_data.iloc[:,-1]
data_dmatrix = xgb.DMatrix(data=X,label=y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# ### XGBoost

# %%
# fit model and tune parameter

import xgboost as xgb
from sklearn.model_selection import GridSearchCV 
xg_reg = xgb.XGBRegressor(objective ='reg:linear', 
                          colsample_bytree = 0.3, 
                          learning_rate = 0.1,
                          max_depth =5,
                          alpha = 10, 
                          n_estimators = 10,
                          verbosity = 0,
                          random_state=123)

test_params = {
 'max_depth':[1,2,5],
 'n_estimators':[10,20,50]   
    
}

model = GridSearchCV(estimator = xg_reg, param_grid = test_params)
model.fit(X_train,y_train)
print ("parameter selected:",model.best_params_)
# Out:
# parameter selected: {'max_depth': 5, 'n_estimators': 50}

# %%
# train and fit
xg_reg = xgb.XGBRegressor(objective ='reg:linear', 
                          colsample_bytree = 0.3, 
                          learning_rate = 0.1,
                          max_depth =5,
                          alpha = 10, 
                          n_estimators = 50)
xg_reg.fit(X_train,y_train)

# %%
# evaluate

import seaborn as sns
preds_test = xg_reg.predict(X_test)
preds_train = xg_reg.predict(X_train)
rmse_train = np.sqrt(mean_squared_error(y_train, preds_train))
rmse_test = np.sqrt(mean_squared_error(y_test, preds_test))
print (f"rmse_train: {rmse_train}\nrmse_test: {rmse_test}")
eval = {'y_test' : y_test, 'preds' : preds}
df_eval = pd.DataFrame(eval)
ax = sns.regplot(x="y_test", y="preds", data=df_eval)
# Out:
# rmse_train: 2.291346363453096
# rmse_test: 4.147070836699256

# %%
# check feature importance

import matplotlib.pyplot as plt
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %% [markdown]
# ### LightGBM

# %%
import lightgbm as lgb

hyper_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['l1','l2'],
    'learning_rate': 0.005,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.7,
    'bagging_freq': 10,
    'verbose': 0,
    "max_depth": 3,
    "num_leaves": 128,  
    "max_bin": 512,
    "num_iterations": 100
}
gbm = lgb.LGBMRegressor(**hyper_params)

# %%
gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric='l1',
        early_stopping_rounds=100)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000360 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l1: 6.74718	valid_0's l2: 82.8093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l1: 6.72392	valid_0's l2: 82.2737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l1: 6.70078	valid_0's l2: 81.7438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l1: 6.67776	valid_0's l2: 81.2195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l1: 6.65485	valid_0's l2: 80.7008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l1: 6.63206	valid_0's l2: 80.1875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l1: 6.60531	valid_0's l2: 79.6245
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l1: 6.58273	valid_0's l2: 79.121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l1: 6.56027	valid_0's l2: 78.6228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l1: 6.53984	valid_0's l2: 78.1885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l1: 6.51766	valid_0's l2: 77.6786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l1: 6.4956	valid_0's l2: 77.1744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l1: 6.47364	valid_0's l2: 76.6758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l1: 6.45179	valid_0's l2: 76.1828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l1: 6.43124	valid_0's l2: 75.7321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l1: 6.40992	valid_0's l2: 75.2552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l1: 6.38905	valid_0's l2: 74.7837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l1: 6.36925	valid_0's l2: 74.3481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l1: 6.34527	valid_0's l2: 73.8149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l1: 6.32452	valid_0's l2: 73.3523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l1: 6.29938	valid_0's l2: 72.8316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l1: 6.27908	valid_0's l2: 72.3638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l1: 6.25888	valid_0's l2: 71.9012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l1: 6.23879	valid_0's l2: 71.4436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l1: 6.21879	valid_0's l2: 70.9911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l1: 6.1989	valid_0's l2: 70.5435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l1: 6.17776	valid_0's l2: 70.096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l1: 6.15805	valid_0's l2: 69.6582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l1: 6.13712	valid_0's l2: 69.2203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l1: 6.1177	valid_0's l2: 68.792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l1: 6.09497	valid_0's l2: 68.3416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l1: 6.07484	valid_0's l2: 67.9593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l1: 6.05232	valid_0's l2: 67.5175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l1: 6.03172	valid_0's l2: 67.1241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l1: 6.01123	valid_0's l2: 66.735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l1: 5.99084	valid_0's l2: 66.3502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l1: 5.97055	valid_0's l2: 65.9695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l1: 5.95036	valid_0's l2: 65.593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l1: 5.93094	valid_0's l2: 65.2384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l1: 5.91095	valid_0's l2: 64.8699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l1: 5.89159	valid_0's l2: 64.4756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l1: 5.87232	valid_0's l2: 64.0854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l1: 5.85315	valid_0's l2: 63.6993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l1: 5.83407	valid_0's l2: 63.3172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l1: 5.81509	valid_0's l2: 62.939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l1: 5.7962	valid_0's l2: 62.5648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l1: 5.77741	valid_0's l2: 62.1945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l1: 5.75739	valid_0's l2: 61.7993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l1: 5.73849	valid_0's l2: 61.4319
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l1: 5.71998	valid_0's l2: 61.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l1: 5.6994	valid_0's l2: 60.6702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l1: 5.6792	valid_0's l2: 60.2719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l1: 5.66244	valid_0's l2: 59.9243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l1: 5.64688	valid_0's l2: 59.6044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's l1: 5.62712	valid_0's l2: 59.217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's l1: 5.61059	valid_0's l2: 58.8797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's l1: 5.59414	valid_0's l2: 58.546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's l1: 5.57777	valid_0's l2: 58.216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's l1: 5.56148	valid_0's l2: 57.8897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l1: 5.54455	valid_0's l2: 57.5508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's l1: 5.52899	valid_0's l2: 57.2616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's l1: 5.513	valid_0's l2: 56.971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's l1: 5.49766	valid_0's l2: 56.6991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's l1: 5.48233	valid_0's l2: 56.4192
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's l1: 5.46713	valid_0's l2: 56.1425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's l1: 5.44905	valid_0's l2: 55.7721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's l1: 5.43393	valid_0's l2: 55.5114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's l1: 5.41822	valid_0's l2: 55.231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's l1: 5.40259	valid_0's l2: 54.9538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's l1: 5.3848	valid_0's l2: 54.5955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's l1: 5.36873	valid_0's l2: 54.3074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's l1: 5.35274	valid_0's l2: 54.0226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's l1: 5.33683	valid_0's l2: 53.7412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's l1: 5.32063	valid_0's l2: 53.4522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's l1: 5.3062	valid_0's l2: 53.2128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's l1: 5.29051	valid_0's l2: 52.9407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's l1: 5.2749	valid_0's l2: 52.6718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's l1: 5.259	valid_0's l2: 52.3954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's l1: 5.24354	valid_0's l2: 52.1328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's l1: 5.2278	valid_0's l2: 51.8627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's l1: 5.21038	valid_0's l2: 51.5511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's l1: 5.19215	valid_0's l2: 51.2312
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's l1: 5.17491	valid_0's l2: 50.9269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's l1: 5.16019	valid_0's l2: 50.7116
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's l1: 5.14243	valid_0's l2: 50.4069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's l1: 5.12455	valid_0's l2: 50.1006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's l1: 5.10763	valid_0's l2: 49.8095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's l1: 5.0932	valid_0's l2: 49.6042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's l1: 5.07615	valid_0's l2: 49.3184
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's l1: 5.0588	valid_0's l2: 49.03
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's l1: 5.04319	valid_0's l2: 48.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's l1: 5.02765	valid_0's l2: 48.5726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's l1: 5.0122	valid_0's l2: 48.3479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's l1: 4.99663	valid_0's l2: 48.137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's l1: 4.98132	valid_0's l2: 47.9172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's l1: 4.96611	valid_0's l2: 47.7001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's l1: 4.95148	valid_0's l2: 47.4911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's l1: 4.93656	valid_0's l2: 47.2789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's l1: 4.91836	valid_0's l2: 47.0124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's l1: 4.90394	valid_0's l2: 46.8103
# LGBMRegressor(bagging_fraction=0.7, bagging_freq=10, feature_fraction=0.9,
#               learning_rate=0.005, max_bin=512, max_depth=3,
#               metric=['l1', 'l2'], num_iterations=100, num_leaves=128,
#               objective='regression', task='train', verbose=0)

# %%
# evaluate

import seaborn as sns
preds_train = gbm.predict(X_train, num_iteration=gbm.best_iteration_)
preds_test = gbm.predict(X_test, num_iteration=gbm.best_iteration_)
rmse_train = np.sqrt(mean_squared_error(y_train, preds_train))
rmse_test = np.sqrt(mean_squared_error(y_test, preds_test))
print (f"rmse_train: {rmse_train}\nrmse_test: {rmse_test}")
eval = {'y_test' : y_test, 'preds' : preds_test}
df_eval = pd.DataFrame(eval)
ax = sns.regplot(x="y_test", y="preds", data=df_eval)
# Out:
# rmse_train: 6.5552117033706905
# rmse_test: 6.841806565271045

# %%
# check feature importance
lgb.plot_importance(gbm)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# ### LightGBM for classification

# %%
from sklearn.datasets import load_iris
iris = load_iris()
df_data = pd.DataFrame(iris.data)
df_data.columns = iris.feature_names
df_data['CAT'] = iris.target
df_data.sample(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 42                 4.4               3.2                1.3               0.2
# 84                 5.4               3.0                4.5               1.5
# 5                  5.4               3.9                1.7               0.4
# 109                7.2               3.6                6.1               2.5
# 77                 6.7               3.0                5.0               1.7
#
#      CAT
# 42     0
# 84     1
# 5      0
# 109    2
# 77     1

# %%
X, y = df_data.iloc[:,:-1],df_data.iloc[:,-1]
data_dmatrix = xgb.DMatrix(data=X,label=y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
hyper_params = {
#      'application': 'binary',
#      'objective': 'binary',
#     'metric': 'auc',
    #'is_unbalance': 'true',
    'boosting': 'gbdt',
    'num_leaves': 128,
    'feature_fraction': 0.5,
    'bagging_fraction': 0.5,
    'bagging_freq': 20,
    'learning_rate': 0.05,
    'verbose': 0
}
gbm = lgb.LGBMClassifier(**hyper_params)

# %%
gbm.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(bagging_fraction=0.5, bagging_freq=20, boosting='gbdt',
#                feature_fraction=0.5, learning_rate=0.05, num_leaves=128,
#                verbose=0)

# %%
preds_train = gbm.predict(X_train)
preds_test = gbm.predict(X_test)
rmse_train = np.sqrt(mean_squared_error(y_train, preds_train))
rmse_test = np.sqrt(mean_squared_error(y_test, preds_test))
print (f"rmse_train: {rmse_train}\nrmse_test: {rmse_test}")
eval = {'y_test' : y_test, 'preds' : preds_test}
df_eval = pd.DataFrame(eval)
ax = sns.pointplot('y_test', 'preds',data=df_eval, join=False)
# Out:
# rmse_train: 0.18257418583505536
# rmse_test: 0.2581988897471611
